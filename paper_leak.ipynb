# %%
import pandas as pd

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\User\Downloads\PAPER_LEAK_ANALYSIS

# %%
import pandas as pd

df = pd.read_csv("Paper_leaks_India.csv", encoding="cp1252")
df.head()
# Out:
#   Date of Exam/Incident                                          Exam Name  \
# 0            26-08-2024  B.Ed. 4th Sem Exam : Creating an Inclusive School
# 1            04-08-2024                                  MBA 1st year Exam
# 2            06-07-2024               Foreign Medical Graduate Examination
# 3            30-06-2024                  Agriculture Development Officers
# 4            18-06-2024                                       UGC NET 2024
#
#                                      Conducting Body Conducting Body Type  \
# 0           Tamil Nadu Teachers Education University                State
# 1                             Pondicherry University              Central
# 2  National Board of Examinations in Medical Scie...              Central
# 3                    Punjab Public Service Comission                State
# 4                            National Testing Agency              Central
#
#   Area(s) of Incident Leak Confirmation Status  \
# 0           Tamilnadu                  accused
# 1         Pondicherry                confirmed
# 2              Kerala                  accused
# 3              Punjab                  accused
# 4           All India                  accused
#
#                              Action taken  \
# 0         Alternative Question Paper Used
# 1                          Exam Cancelled
# 2  Legal action taken and claim dismissed
# 3                                     NaN
# 4                                No Rexam
#
#                              Note about action Taken  \
# 0                    Alternative Question Paper Used
# 1                    Legal action against exam mafia
# 2  No Rexam and checking of evidence, claim dismi...
# 3                                           No Rexam
# 4  Exam cancellation decision overruled by Suprem...
#
#                                Note about incident  \
# 0         Paper leaked on social media before exam
# 1         Paper leaked on social media before exam
# 2                     Paper leaked on social media
# 3  Claim: Offical demanded bribe for leaking paper
# 4                         accusation of paper leak
#
#                                          References   Appeared Students
# 0  TNTEU registrar relieved after reports of B.Ed...                NaN
# 1  Pondicherry University First-year MBBS Exam Pa...                NaN
# 2  ‘So far no evidence’: Kerala Police on FMGE ‘p...                NaN
# 3  Now, ADO recruitment exam in Punjab under pape...                NaN
# 4  Supreme Court upholds decision to cancel UGC N...                NaN

# %%
df.head()
# Out:
#   Date of Exam/Incident                                          Exam Name  \
# 0            26-08-2024  B.Ed. 4th Sem Exam : Creating an Inclusive School
# 1            04-08-2024                                  MBA 1st year Exam
# 2            06-07-2024               Foreign Medical Graduate Examination
# 3            30-06-2024                  Agriculture Development Officers
# 4            18-06-2024                                       UGC NET 2024
#
#                                      Conducting Body Conducting Body Type  \
# 0           Tamil Nadu Teachers Education University                State
# 1                             Pondicherry University              Central
# 2  National Board of Examinations in Medical Scie...              Central
# 3                    Punjab Public Service Comission                State
# 4                            National Testing Agency              Central
#
#   Area(s) of Incident Leak Confirmation Status  \
# 0           Tamilnadu                  accused
# 1         Pondicherry                confirmed
# 2              Kerala                  accused
# 3              Punjab                  accused
# 4           All India                  accused
#
#                              Action taken  \
# 0         Alternative Question Paper Used
# 1                          Exam Cancelled
# 2  Legal action taken and claim dismissed
# 3                                     NaN
# 4                                No Rexam
#
#                              Note about action Taken  \
# 0                    Alternative Question Paper Used
# 1                    Legal action against exam mafia
# 2  No Rexam and checking of evidence, claim dismi...
# 3                                           No Rexam
# 4  Exam cancellation decision overruled by Suprem...
#
#                                Note about incident  \
# 0         Paper leaked on social media before exam
# 1         Paper leaked on social media before exam
# 2                     Paper leaked on social media
# 3  Claim: Offical demanded bribe for leaking paper
# 4                         accusation of paper leak
#
#                                          References   Appeared Students
# 0  TNTEU registrar relieved after reports of B.Ed...                NaN
# 1  Pondicherry University First-year MBBS Exam Pa...                NaN
# 2  ‘So far no evidence’: Kerala Police on FMGE ‘p...                NaN
# 3  Now, ADO recruitment exam in Punjab under pape...                NaN
# 4  Supreme Court upholds decision to cancel UGC N...                NaN

# %%
df.tail()
# Out:
#    Date of Exam/Incident                                          Exam Name  \
# 61            01-05-2016                                  NEET Phase 1 2016
# 62            25-05-2015                                       UP CPMT 2015
# 63            03-05-2015                                         AIPMT 2015
# 64            30-03-2015  Provincial civil services preliminary examination
# 65            23-06-2014                                       UP CPMT 2014
#
#                                   Conducting Body Conducting Body Type  \
# 61                                           CBSE              Central
# 62     King George's Medical University , Lucknow                State
# 63                                           CBSE              Central
# 64         Uttar Pradesh Public Service Comission                State
# 65  King George's Medical University , Ghaziabadd                State
#
#    Area(s) of Incident Leak Confirmation Status        Action taken  \
# 61       Uttar Pradesh                confirmed  Legal action taken
# 62       Uttar Pradesh                confirmed  Legal action taken
# 63           All India                confirmed      Exam Cancelled
# 64       Uttar Pradesh                confirmed      Exam Cancelled
# 65       Uttar Pradesh                confirmed      Exam Cancelled
#
#             Note about action Taken                       Note about incident  \
# 61                         No Rexam                         Cheating reported
# 62                         No Rexam              Paper leaked on social media
# 63  Legal action against exam mafia              Paper leaked on social media
# 64  Legal action against exam mafia  Paper leaked on social media before exam
# 65  Legal action against exam mafia              Paper leaked on social media
#
#                                           References   Appeared Students
# 61  NEET Phase 1 2016: Paper leaked in Varanasi - ...                NaN
# 62  Bid to leak UP CPMT answers: 3 MBBS students a...                NaN
# 63  AIPMT cancelled, CBSE told to reconduct exam -...                NaN
# 64  Uttar Pradesh civil services exam cancelled af...                NaN
# 65  CPMT 2014 paper leak: Aspirants dejected, dema...                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date of Exam/Incident     66 non-null     object
#  1   Exam Name                 66 non-null     object
#  2   Conducting Body           66 non-null     object
#  3   Conducting Body Type      66 non-null     object
#  4   Area(s) of Incident       66 non-null     object
#  5   Leak Confirmation Status  66 non-null     object
#  6   Action taken              64 non-null     object
#  7   Note about action Taken   66 non-null     object
#  8   Note about incident       66 non-null     object
#  9   References                66 non-null     object
#  10  Appeared Students         1 non-null      float64
# dtypes: float64(1), object(10)
# memory usage: 5.8+ KB

# %%
df.shape
# Out:
# (66, 11)

# %%
df.columns
# Out:
# Index(['Date of Exam/Incident', 'Exam Name', 'Conducting Body',
#        'Conducting Body Type', 'Area(s) of Incident',
#        'Leak Confirmation Status', 'Action taken', 'Note about action Taken',
#        'Note about incident', 'References ', 'Appeared Students'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date of Exam/Incident        0
# Exam Name                    0
# Conducting Body              0
# Conducting Body Type         0
# Area(s) of Incident          0
# Leak Confirmation Status     0
# Action taken                 2
# Note about action Taken      0
# Note about incident          0
# References                   0
# Appeared Students           65
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Appeared Students
# count                1.0
# mean               183.0
# std                  NaN
# min                183.0
# 25%                183.0
# 50%                183.0
# 75%                183.0
# max                183.0

# %%
df.describe(include='all')
# Out:
#        Date of Exam/Incident                     Exam Name  \
# count                     66                            66
# unique                    66                            63
# top               26-08-2024  High School Mathematics Exam
# freq                       1                             3
# mean                     NaN                           NaN
# std                      NaN                           NaN
# min                      NaN                           NaN
# 25%                      NaN                           NaN
# 50%                      NaN                           NaN
# 75%                      NaN                           NaN
# max                      NaN                           NaN
#
#                                           Conducting Body  \
# count                                                  66
# unique                                                 53
# top     Maharashtra State Board of Secondary and Highe...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Conducting Body Type Area(s) of Incident Leak Confirmation Status  \
# count                    66                  66                       66
# unique                    3                  24                        2
# top                   State       Uttar Pradesh                confirmed
# freq                     50                  11                       48
# mean                    NaN                 NaN                      NaN
# std                     NaN                 NaN                      NaN
# min                     NaN                 NaN                      NaN
# 25%                     NaN                 NaN                      NaN
# 50%                     NaN                 NaN                      NaN
# 75%                     NaN                 NaN                      NaN
# max                     NaN                 NaN                      NaN
#
#           Action taken Note about action Taken           Note about incident  \
# count               64                      66                            66
# unique              12                      22                            29
# top     Exam Cancelled                No Rexam  Paper leaked on social media
# freq                30                      13                            28
# mean               NaN                     NaN                           NaN
# std                NaN                     NaN                           NaN
# min                NaN                     NaN                           NaN
# 25%                NaN                     NaN                           NaN
# 50%                NaN                     NaN                           NaN
# 75%                NaN                     NaN                           NaN
# max                NaN                     NaN                           NaN
#
#                                               References   Appeared Students
# count                                                  66                1.0
# unique                                                 66                NaN
# top     TNTEU registrar relieved after reports of B.Ed...                NaN
# freq                                                    1                NaN
# mean                                                  NaN              183.0
# std                                                   NaN                NaN
# min                                                   NaN              183.0
# 25%                                                   NaN              183.0
# 50%                                                   NaN              183.0
# 75%                                                   NaN              183.0
# max                                                   NaN              183.0

# %%
clean_df = df.copy()

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date of Exam/Incident     66 non-null     object
#  1   Exam Name                 66 non-null     object
#  2   Conducting Body           66 non-null     object
#  3   Conducting Body Type      66 non-null     object
#  4   Area(s) of Incident       66 non-null     object
#  5   Leak Confirmation Status  66 non-null     object
#  6   Action taken              64 non-null     object
#  7   Note about action Taken   66 non-null     object
#  8   Note about incident       66 non-null     object
#  9   References                66 non-null     object
#  10  Appeared Students         1 non-null      float64
# dtypes: float64(1), object(10)
# memory usage: 5.8+ KB

# %%
clean_df = clean_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
clean_df.head()
# Out:
#   Date of Exam/Incident                                          Exam Name  \
# 0            26-08-2024  B.Ed. 4th Sem Exam : Creating an Inclusive School
# 1            04-08-2024                                  MBA 1st year Exam
# 2            06-07-2024               Foreign Medical Graduate Examination
# 3            30-06-2024                   Agriculture Development Officers
# 4            18-06-2024                                       UGC NET 2024
#
#                                      Conducting Body Conducting Body Type  \
# 0           Tamil Nadu Teachers Education University                State
# 1                             Pondicherry University              Central
# 2  National Board of Examinations in Medical Scie...              Central
# 3                    Punjab Public Service Comission                State
# 4                            National Testing Agency              Central
#
#   Area(s) of Incident Leak Confirmation Status  \
# 0           Tamilnadu                  accused
# 1         Pondicherry                confirmed
# 2              Kerala                  accused
# 3              Punjab                  accused
# 4           All India                  accused
#
#                              Action taken  \
# 0         Alternative Question Paper Used
# 1                          Exam Cancelled
# 2  Legal action taken and claim dismissed
# 3                                     NaN
# 4                                No Rexam
#
#                              Note about action Taken  \
# 0                    Alternative Question Paper Used
# 1                    Legal action against exam mafia
# 2  No Rexam and checking of evidence, claim dismi...
# 3                                           No Rexam
# 4  Exam cancellation decision overruled by Suprem...
#
#                                Note about incident  \
# 0         Paper leaked on social media before exam
# 1         Paper leaked on social media before exam
# 2                     Paper leaked on social media
# 3  Claim: Offical demanded bribe for leaking paper
# 4                         accusation of paper leak
#
#                                          References   Appeared Students
# 0  TNTEU registrar relieved after reports of B.Ed...                NaN
# 1  Pondicherry University First-year MBBS Exam Pa...                NaN
# 2  ‘So far no evidence’: Kerala Police on FMGE ‘p...                NaN
# 3  Now, ADO recruitment exam in Punjab under pape...                NaN
# 4  Supreme Court upholds decision to cancel UGC N...                NaN

# %%
clean_df["Action taken"] = clean_df["Action taken"].fillna("Unknown")

# %%
clean_df.isnull().sum()
# Out:
# Date of Exam/Incident        0
# Exam Name                    0
# Conducting Body              0
# Conducting Body Type         0
# Area(s) of Incident          0
# Leak Confirmation Status     0
# Action taken                 0
# Note about action Taken      0
# Note about incident          0
# References                   0
# Appeared Students           65
# dtype: int64

# %%
clean_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
clean_df.drop(columns=["Appeared Students"], inplace=True)

# %%
clean_df["Action taken"] = clean_df["Action taken"].fillna("Unknown")

# %%
clean_df.isnull().sum()
# Out:
# Date of Exam/Incident       0
# Exam Name                   0
# Conducting Body             0
# Conducting Body Type        0
# Area(s) of Incident         0
# Leak Confirmation Status    0
# Action taken                0
# Note about action Taken     0
# Note about incident         0
# References                  0
# dtype: int64

# %%
clean_df["Date of Exam/Incident"].head(15)
# Out:
# 0     26-08-2024
# 1     04-08-2024
# 2     06-07-2024
# 3     30-06-2024
# 4     18-06-2024
# 5     09-06-2024
# 6     28-05-2024
# 7     28-04-2024
# 8     16-04-2024
# 9     17-03-2024
# 10    17-02-2024
# 11    16-02-2024
# 12    11-02-2024
# 13    26-12-2023
# 14    25-12-2023
# Name: Date of Exam/Incident, dtype: object

# %%
pd.to_datetime(clean_df["Date of Exam/Incident"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18080\3438781684.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(clean_df["Date of Exam/Incident"])
# 0    2024-08-26
# 1    2024-08-04
# 2    2024-07-06
# 3    2024-06-30
# 4    2024-06-18
#         ...
# 61   2016-05-01
# 62   2015-05-25
# 63   2015-05-03
# 64   2015-03-30
# 65   2014-06-23
# Name: Date of Exam/Incident, Length: 66, dtype: datetime64[ns]

# %%
clean_df["Date of Exam/Incident"] = pd.to_datetime(
    clean_df["Date of Exam/Incident"],
    dayfirst=True
)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date of Exam/Incident     66 non-null     datetime64[ns]
#  1   Exam Name                 66 non-null     object
#  2   Conducting Body           66 non-null     object
#  3   Conducting Body Type      66 non-null     object
#  4   Area(s) of Incident       66 non-null     object
#  5   Leak Confirmation Status  66 non-null     object
#  6   Action taken              66 non-null     object
#  7   Note about action Taken   66 non-null     object
#  8   Note about incident       66 non-null     object
#  9   References                66 non-null     object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 5.3+ KB

# %%
clean_df["Year"] = clean_df["Date of Exam/Incident"].dt.year

# %%
clean_df["Month"] = clean_df["Date of Exam/Incident"].dt.month_name()

# %%
clean_df["Month_No"] = clean_df["Date of Exam/Incident"].dt.month

# %%
clean_df["Quarter"] = clean_df["Date of Exam/Incident"].dt.quarter

# %%
clean_df.head()
# Out:
#   Date of Exam/Incident                                          Exam Name  \
# 0            2024-08-26  B.Ed. 4th Sem Exam : Creating an Inclusive School
# 1            2024-08-04                                  MBA 1st year Exam
# 2            2024-07-06               Foreign Medical Graduate Examination
# 3            2024-06-30                   Agriculture Development Officers
# 4            2024-06-18                                       UGC NET 2024
#
#                                      Conducting Body Conducting Body Type  \
# 0           Tamil Nadu Teachers Education University                State
# 1                             Pondicherry University              Central
# 2  National Board of Examinations in Medical Scie...              Central
# 3                    Punjab Public Service Comission                State
# 4                            National Testing Agency              Central
#
#   Area(s) of Incident Leak Confirmation Status  \
# 0           Tamilnadu                  accused
# 1         Pondicherry                confirmed
# 2              Kerala                  accused
# 3              Punjab                  accused
# 4           All India                  accused
#
#                              Action taken  \
# 0         Alternative Question Paper Used
# 1                          Exam Cancelled
# 2  Legal action taken and claim dismissed
# 3                                 Unknown
# 4                                No Rexam
#
#                              Note about action Taken  \
# 0                    Alternative Question Paper Used
# 1                    Legal action against exam mafia
# 2  No Rexam and checking of evidence, claim dismi...
# 3                                           No Rexam
# 4  Exam cancellation decision overruled by Suprem...
#
#                                Note about incident  \
# 0         Paper leaked on social media before exam
# 1         Paper leaked on social media before exam
# 2                     Paper leaked on social media
# 3  Claim: Offical demanded bribe for leaking paper
# 4                         accusation of paper leak
#
#                                          References   Year   Month  Month_No  \
# 0  TNTEU registrar relieved after reports of B.Ed...  2024  August         8
# 1  Pondicherry University First-year MBBS Exam Pa...  2024  August         8
# 2  ‘So far no evidence’: Kerala Police on FMGE ‘p...  2024    July         7
# 3  Now, ADO recruitment exam in Punjab under pape...  2024    June         6
# 4  Supreme Court upholds decision to cancel UGC N...  2024    June         6
#
#    Quarter
# 0        3
# 1        3
# 2        3
# 3        2
# 4        2

# %%
clean_df["Conducting Body"].unique()
# Out:
# array(['Tamil Nadu Teachers Education University',
#        'Pondicherry University',
#        'National Board of Examinations in Medical Sciences (NBEMS)',
#        'Punjab Public Service Comission', 'National Testing Agency',
#        'Tripura Tribal Areas Autonomous District Council',
#        "Devi Ahilya Vishwavidyalaya's (DAVV)", 'VIT',
#        'Bihar Public service Comission',
#        'Jharkhand Public Service Commission',
#        'Uttar Pradesh Police Recruitment and Promotion Board',
#        'Assam Board of Secondary Education',
#        'Uttar Pradesh Public Service Comission', 'Parul University',
#        'West Bengal Board of Primary Education',
#        'Tripura Board of Secondary Education (TBSE)',
#        'Savitribai Phule\xa0Pune\xa0University',
#        'Central Selection Board of Constables, Bihar', 'Private Center',
#        'Barkatullah University', 'Odisha Staff Selection Commission',
#        'AIIMS', 'Punjab School Education Board',
#        'Telangana Board of intermediate Education',
#        'Madhya Pradesh Board of Secondary Education',
#        'Telangana State Public Service Commission',
#        'Maharashtra State Board of Secondary and Higher Secondary Education',
#        'Rajasthan Public Service Commission',
#        'Rajasthan Staff Selection Board',
#        'Himachal Pradesh Staff Selection Commission',
#        'Arunachal Pradesh Public Service Commission',
#        'The Uttar Pradesh Subordinate Services Selection Commission',
#        'Uttar Pradesh State Board of High School and Intermediate Education',
#        'Jammu and Kashmir Services Selection Board',
#        'Bihar School Examination Board',
#        'Maharashtra Housing and Area Development Authority',
#        'Gujarat Subordinate Service Selection Board',
#        'Uttarakhand Subordinate Staff Selection Commission',
#        'Department of Basic Education, Uttar Pradesh',
#        'BOARD OF SECONDARY EDUCATION, Rajasthan',
#        'National Law School of India University',
#        'Railway Recruitment Board', 'Kerala Public Service Commission',
#        'Karnataka School Examination and Assessment Board',
#        'Board of Secondary Education, Odisha',
#        'Gujarat Police Recruitment Board',
#        'Indria Gandhi National Open University', 'CBSE',
#        'Staff Selection Comission',
#        'Himachal Pradesh Board of School Education',
#        'Haryana Public Service Commission',
#        "King George's Medical University\xa0, Lucknow",
#        "King George's Medical University\xa0, Ghaziabadd"], dtype=object)

# %%
clean_df["Conducting Body Type"].unique()
# Out:
# array(['State', 'Central', 'Private'], dtype=object)

# %%
clean_df["Area(s) of Incident"].unique()
# Out:
# array(['Tamilnadu', 'Pondicherry', 'Kerala', 'Punjab', 'All India',
#        'Tripura', 'Madhya Pradesh', 'Bihar', 'Jharkhand', 'Uttar Pradesh',
#        'Assam', 'Gujrat', 'West Bengal', 'Maharasthra', 'Odisha',
#        'Telangana', 'Rajasthan', 'Himachal Pradesh', 'Arunachal Pradesh',
#        'Jammu', 'Uttarakhand', 'Karnataka', 'Delhi', 'Haryana'],
#       dtype=object)

# %%
clean_df["Leak Confirmation Status"].unique()
# Out:
# array(['accused', 'confirmed'], dtype=object)

# %%
clean_df["Action taken"].unique()
# Out:
# array(['Alternative Question Paper Used', 'Exam Cancelled',
#        'Legal action taken and claim dismissed', 'Unknown', 'No Rexam',
#        'Legal action taken', 'Chargesheet', 'Reports Denied',
#        'Claim dissmissed', 'dismissed claim', 'No action taken',
#        'Suspension', 'Exam Cancelled on many centers'], dtype=object)

# %%
clean_df["Conducting Body"].unique()
# Out:
# array(['Tamil Nadu Teachers Education University',
#        'Pondicherry University',
#        'National Board of Examinations in Medical Sciences (NBEMS)',
#        'Punjab Public Service Comission', 'National Testing Agency',
#        'Tripura Tribal Areas Autonomous District Council',
#        "Devi Ahilya Vishwavidyalaya's (DAVV)", 'VIT',
#        'Bihar Public service Comission',
#        'Jharkhand Public Service Commission',
#        'Uttar Pradesh Police Recruitment and Promotion Board',
#        'Assam Board of Secondary Education',
#        'Uttar Pradesh Public Service Comission', 'Parul University',
#        'West Bengal Board of Primary Education',
#        'Tripura Board of Secondary Education (TBSE)',
#        'Savitribai Phule\xa0Pune\xa0University',
#        'Central Selection Board of Constables, Bihar', 'Private Center',
#        'Barkatullah University', 'Odisha Staff Selection Commission',
#        'AIIMS', 'Punjab School Education Board',
#        'Telangana Board of intermediate Education',
#        'Madhya Pradesh Board of Secondary Education',
#        'Telangana State Public Service Commission',
#        'Maharashtra State Board of Secondary and Higher Secondary Education',
#        'Rajasthan Public Service Commission',
#        'Rajasthan Staff Selection Board',
#        'Himachal Pradesh Staff Selection Commission',
#        'Arunachal Pradesh Public Service Commission',
#        'The Uttar Pradesh Subordinate Services Selection Commission',
#        'Uttar Pradesh State Board of High School and Intermediate Education',
#        'Jammu and Kashmir Services Selection Board',
#        'Bihar School Examination Board',
#        'Maharashtra Housing and Area Development Authority',
#        'Gujarat Subordinate Service Selection Board',
#        'Uttarakhand Subordinate Staff Selection Commission',
#        'Department of Basic Education, Uttar Pradesh',
#        'BOARD OF SECONDARY EDUCATION, Rajasthan',
#        'National Law School of India University',
#        'Railway Recruitment Board', 'Kerala Public Service Commission',
#        'Karnataka School Examination and Assessment Board',
#        'Board of Secondary Education, Odisha',
#        'Gujarat Police Recruitment Board',
#        'Indria Gandhi National Open University', 'CBSE',
#        'Staff Selection Comission',
#        'Himachal Pradesh Board of School Education',
#        'Haryana Public Service Commission',
#        "King George's Medical University\xa0, Lucknow",
#        "King George's Medical University\xa0, Ghaziabadd"], dtype=object)

# %%
clean_df.to_csv("Paper_Leaks_Clean.csv", index=False)

# %%
# Total incidents by year
clean_df["Year"].value_counts().sort_index()
# Out:
# Year
# 2014     1
# 2015     3
# 2016     2
# 2017     3
# 2018     5
# 2019     3
# 2020     2
# 2021     8
# 2022    11
# 2023    15
# 2024    13
# Name: count, dtype: int64

# %%
# Top Exam Names
clean_df["Exam Name"].value_counts()
# Out:
# Exam Name
# High School Mathematics Exam                         3
# Constable Exam                                       2
# B.Ed. 4th Sem Exam : Creating an Inclusive School    1
# JE Exam                                              1
# Class 12th English                                   1
#                                                     ..
# Class 2nd Teacher Recruitment : GK Question Paper    1
# Group 1 Prelims                                      1
# Diploma in Elementary Education                      1
# Forest Guard Recruitment                             1
# UP CPMT 2014                                         1
# Name: count, Length: 63, dtype: int64

# %%
# Top Conducting Bodies
clean_df["Conducting Body"].value_counts()
# Out:
# Conducting Body
# Maharashtra State Board of Secondary and Higher Secondary Education    3
# Uttar Pradesh Public Service Comission                                 3
# CBSE                                                                   3
# Bihar Public service Comission                                         2
# Telangana State Public Service Commission                              2
# Bihar School Examination Board                                         2
# Railway Recruitment Board                                              2
# Assam Board of Secondary Education                                     2
# West Bengal Board of Primary Education                                 2
# National Testing Agency                                                2
# Indria Gandhi National Open University                                 1
# Department of Basic Education, Uttar Pradesh                           1
# Uttar Pradesh State Board of High School and Intermediate Education    1
# Jammu and Kashmir Services Selection Board                             1
# King George's Medical University , Lucknow                             1
# Haryana Public Service Commission                                      1
# Maharashtra Housing and Area Development Authority                     1
# Gujarat Subordinate Service Selection Board                            1
# Uttarakhand Subordinate Staff Selection Commission                     1
# BOARD OF SECONDARY EDUCATION, Rajasthan                                1
# Gujarat Police Recruitment Board                                       1
# National Law School of India University                                1
# Kerala Public Service Commission                                       1
# Karnataka School Examination and Assessment Board                      1
# Arunachal Pradesh Public Service Commission                            1
# Board of Secondary Education, Odisha                                   1
# Himachal Pradesh Board of School Education                             1
# Staff Selection Comission                                              1
# The Uttar Pradesh Subordinate Services Selection Commission            1
# Tamil Nadu Teachers Education University                               1
# Himachal Pradesh Staff Selection Commission                            1
# Savitribai Phule Pune University                                       1
# National Board of Examinations in Medical Sciences (NBEMS)             1
# Punjab Public Service Comission                                        1
# Tripura Tribal Areas Autonomous District Council                       1
# Devi Ahilya Vishwavidyalaya's (DAVV)                                   1
# VIT                                                                    1
# Jharkhand Public Service Commission                                    1
# Uttar Pradesh Police Recruitment and Promotion Board                   1
# Parul University                                                       1
# Tripura Board of Secondary Education (TBSE)                            1
# Central Selection Board of Constables, Bihar                           1
# Rajasthan Staff Selection Board                                        1
# Private Center                                                         1
# Barkatullah University                                                 1
# Odisha Staff Selection Commission                                      1
# AIIMS                                                                  1
# Punjab School Education Board                                          1
# Telangana Board of intermediate Education                              1
# Madhya Pradesh Board of Secondary Education                            1
# Pondicherry University                                                 1
# Rajasthan Public Service Commission                                    1
# King George's Medical University , Ghaziabadd                          1
# Name: count, dtype: int64

# %%
# State-wise incidents
clean_df["Area(s) of Incident"].value_counts()
# Out:
# Area(s) of Incident
# Uttar Pradesh        11
# All India             7
# Maharasthra           6
# Bihar                 5
# Gujrat                3
# Kerala                3
# Rajasthan             3
# Madhya Pradesh        3
# Telangana             3
# Himachal Pradesh      2
# Odisha                2
# West Bengal           2
# Assam                 2
# Delhi                 2
# Tripura               2
# Punjab                2
# Karnataka             1
# Jammu                 1
# Uttarakhand           1
# Tamilnadu             1
# Arunachal Pradesh     1
# Pondicherry           1
# Jharkhand             1
# Haryana               1
# Name: count, dtype: int64

# %%
# Leak confirmation status
clean_df["Leak Confirmation Status"].value_counts()
# Out:
# Leak Confirmation Status
# confirmed    48
# accused      18
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv("Paper_Leaks_Clean.csv", encoding="cp1252")
df.head()
# Out:
#   Date of Exam/Incident                                          Exam Name  \
# 0            2024-08-26  B.Ed. 4th Sem Exam : Creating an Inclusive School
# 1            2024-08-04                                  MBA 1st year Exam
# 2            2024-07-06               Foreign Medical Graduate Examination
# 3            2024-06-30                   Agriculture Development Officers
# 4            2024-06-18                                       UGC NET 2024
#
#                                      Conducting Body Conducting Body Type  \
# 0           Tamil Nadu Teachers Education University                State
# 1                             Pondicherry University              Central
# 2  National Board of Examinations in Medical Scie...              Central
# 3                    Punjab Public Service Comission                State
# 4                            National Testing Agency              Central
#
#   Area(s) of Incident Leak Confirmation Status  \
# 0           Tamilnadu                  accused
# 1         Pondicherry                confirmed
# 2              Kerala                  accused
# 3              Punjab                  accused
# 4           All India                  accused
#
#                              Action taken  \
# 0         Alternative Question Paper Used
# 1                          Exam Cancelled
# 2  Legal action taken and claim dismissed
# 3                                 Unknown
# 4                                No Rexam
#
#                              Note about action Taken  \
# 0                    Alternative Question Paper Used
# 1                    Legal action against exam mafia
# 2  No Rexam and checking of evidence, claim dismi...
# 3                                           No Rexam
# 4  Exam cancellation decision overruled by Suprem...
#
#                                Note about incident  \
# 0         Paper leaked on social media before exam
# 1         Paper leaked on social media before exam
# 2                     Paper leaked on social media
# 3  Claim: Offical demanded bribe for leaking paper
# 4                         accusation of paper leak
#
#                                          References   Year   Month  Month_No  \
# 0  TNTEU registrar relieved after reports of B.Ed...  2024  August         8
# 1  Pondicherry University First-year MBBS Exam Pa...  2024  August         8
# 2  â€˜So far no evidenceâ€™: Kerala Police on FMG...  2024    July         7
# 3  Now, ADO recruitment exam in Punjab under pape...  2024    June         6
# 4  Supreme Court upholds decision to cancel UGC N...  2024    June         6
#
#    Quarter
# 0        3
# 1        3
# 2        3
# 3        2
# 4        2

# %%
clean_df = df.copy()

# %%
EDA (Exploratory Data Analysis)

# %%
# Total incidents by year
clean_df["Year"].value_counts().sort_index()
# Out:
# Year
# 2014     1
# 2015     3
# 2016     2
# 2017     3
# 2018     5
# 2019     3
# 2020     2
# 2021     8
# 2022    11
# 2023    15
# 2024    13
# Name: count, dtype: int64

# %%
# Top Exam Names
clean_df["Exam Name"].value_counts()
# Out:
# Exam Name
# High School Mathematics Exam                         3
# Constable Exam                                       2
# B.Ed. 4th Sem Exam : Creating an Inclusive School    1
# JE Exam                                              1
# Class 12th English                                   1
#                                                     ..
# Class 2nd Teacher Recruitment : GK Question Paper    1
# Group 1 Prelims                                      1
# Diploma in Elementary Education                      1
# Forest Guard Recruitment                             1
# UP CPMT 2014                                         1
# Name: count, Length: 63, dtype: int64

# %%
# Top Conducting Bodies
clean_df["Conducting Body"].value_counts()
# Out:
# Conducting Body
# Maharashtra State Board of Secondary and Higher Secondary Education    3
# Uttar Pradesh Public Service Comission                                 3
# CBSE                                                                   3
# Bihar Public service Comission                                         2
# Telangana State Public Service Commission                              2
# Bihar School Examination Board                                         2
# Railway Recruitment Board                                              2
# Assam Board of Secondary Education                                     2
# West Bengal Board of Primary Education                                 2
# National Testing Agency                                                2
# Indria Gandhi National Open University                                 1
# Department of Basic Education, Uttar Pradesh                           1
# Uttar Pradesh State Board of High School and Intermediate Education    1
# Jammu and Kashmir Services Selection Board                             1
# King George's Medical UniversityÂ , Lucknow                            1
# Haryana Public Service Commission                                      1
# Maharashtra Housing and Area Development Authority                     1
# Gujarat Subordinate Service Selection Board                            1
# Uttarakhand Subordinate Staff Selection Commission                     1
# BOARD OF SECONDARY EDUCATION, Rajasthan                                1
# Gujarat Police Recruitment Board                                       1
# National Law School of India University                                1
# Kerala Public Service Commission                                       1
# Karnataka School Examination and Assessment Board                      1
# Arunachal Pradesh Public Service Commission                            1
# Board of Secondary Education, Odisha                                   1
# Himachal Pradesh Board of School Education                             1
# Staff Selection Comission                                              1
# The Uttar Pradesh Subordinate Services Selection Commission            1
# Tamil Nadu Teachers Education University                               1
# Himachal Pradesh Staff Selection Commission                            1
# Savitribai PhuleÂ PuneÂ University                                     1
# National Board of Examinations in Medical Sciences (NBEMS)             1
# Punjab Public Service Comission                                        1
# Tripura Tribal Areas Autonomous District Council                       1
# Devi Ahilya Vishwavidyalaya's (DAVV)                                   1
# VIT                                                                    1
# Jharkhand Public Service Commission                                    1
# Uttar Pradesh Police Recruitment and Promotion Board                   1
# Parul University                                                       1
# Tripura Board of Secondary Education (TBSE)                            1
# Central Selection Board of Constables, Bihar                           1
# Rajasthan Staff Selection Board                                        1
# Private Center                                                         1
# Barkatullah University                                                 1
# Odisha Staff Selection Commission                                      1
# AIIMS                                                                  1
# Punjab School Education Board                                          1
# Telangana Board of intermediate Education                              1
# Madhya Pradesh Board of Secondary Education                            1
# Pondicherry University                                                 1
# Rajasthan Public Service Commission                                    1
# King George's Medical UniversityÂ , Ghaziabadd                         1
# Name: count, dtype: int64

# %%
# State-wise incidents
clean_df["Area(s) of Incident"].value_counts()
# Out:
# Area(s) of Incident
# Uttar Pradesh        11
# All India             7
# Maharasthra           6
# Bihar                 5
# Gujrat                3
# Kerala                3
# Rajasthan             3
# Madhya Pradesh        3
# Telangana             3
# Himachal Pradesh      2
# Odisha                2
# West Bengal           2
# Assam                 2
# Delhi                 2
# Tripura               2
# Punjab                2
# Karnataka             1
# Jammu                 1
# Uttarakhand           1
# Tamilnadu             1
# Arunachal Pradesh     1
# Pondicherry           1
# Jharkhand             1
# Haryana               1
# Name: count, dtype: int64

# %%
# Leak confirmation status
clean_df["Leak Confirmation Status"].value_counts()
# Out:
# Leak Confirmation Status
# confirmed    48
# accused      18
# Name: count, dtype: int64

# %%
clean_df["Exam Name"].value_counts().head(10)
# Out:
# Exam Name
# High School Mathematics Exam                         3
# Constable Exam                                       2
# B.Ed. 4th Sem Exam : Creating an Inclusive School    1
# JE Exam                                              1
# Class 12th English                                   1
# sub-inspector recruitment examination                1
# MHADA Exam                                           1
# Head Clerk                                           1
# UKSSSC Exam                                          1
# Uttar Pradesh Teacher Eligbility Test                1
# Name: count, dtype: int64
